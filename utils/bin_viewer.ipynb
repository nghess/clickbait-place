# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Binary Data from Bonsai MatrixWriter

# %%
# Params
n_channels = 4
sample_hz = 1000
mat_file = r"D:\clickbait-place\data\dry-morris-maze-visual\2206\d0\040926_2206_d0_rhd2000.bin"

# Load Data
matrix = np.fromfile(mat_file, dtype='uint16')

# %%
# Data info
print(f"shape: {matrix.shape}")
print(f"min: {np.min(matrix)}")
print(f"max: {np.max(matrix)}")
print(f"duration: {(len(matrix)//n_channels)//1000}s")
# Out:
# shape: (3669120,)
# min: 0
# max: 65528
# duration: 917s

# %%
end
# Out:
# 194160

# %%
# Plot params
window = 4000
end = len(matrix)

# %% [markdown]
# ### Plot channels

# %%
sniff = matrix[12500:15000:n_channels]
plt.plot(sniff)

# %%
ttl = matrix[1:4000:n_channels]
plt.plot(ttl)

# %%
reward_state = matrix[2:end:n_channels]
plt.plot(reward_state)

# %%
iti = matrix[3:end:n_channels]
plt.plot(iti)
